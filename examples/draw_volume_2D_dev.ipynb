# %% [markdown]
# ## **Draw volume 2D**
#
#
# The `draw` function plots a 3D representation of the volume. But is not always easy to spot potential overpal between hodoscopes. Having a 2D plotting function might come in handy.

# %%
from volume.hodoscope_init_config import get_overlap_hod_config, get_standard_hod_config

volume = get_overlap_hod_config()

from plotting.plotting import draw_volume_2D
draw_volume_2D(volume)

# %%
volume = get_standard_hod_config()
draw_volume_2D(volume)
